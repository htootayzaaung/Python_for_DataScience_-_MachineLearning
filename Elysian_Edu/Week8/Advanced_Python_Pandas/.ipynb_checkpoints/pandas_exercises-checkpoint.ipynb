# %%
import pandas as pd
df = pd.read_excel('SaleData.xlsx')
#print(df)
import numpy as np

# %%
df.head(2)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0

# %% [markdown]
# # Pivot

# %% [markdown]
# ## create pivot with multiple index (Manager and SalesMan)

# %%
#pd.pivot_table(df,index=["Manager","SalesMan"])

# %%
#pd.pivot_table(df,index=["Region","SalesMan"])

# %% [markdown]
# ## Create a Pivot table and find the total sale amount region wise, manager wise

# %%
#pd.pivot_table(df,index = ["Region","Manager"], values = ["Sale_amt"],aggfunc=np.sum)

# %% [markdown]
# ## item wise unit sold

# %%
df.head(2)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0

# %%
print(pd.pivot_table(df,index=["Item"], values="Units", aggfunc=np.sum))
# Out:
#               Units
# Item
# Cell Phone    278.0
# Desk           10.0
# Home Theater  722.0
# Television    716.0
# Video Games   395.0

# %% [markdown]
# ## count the manager wise sale and mean value of sale amount

# %%
print(pd.pivot_table(df,index=["Manager"],values=["Sale_amt"],aggfunc=[np.mean,len]))
# Out:
#                  mean      len
#              Sale_amt Sale_amt
# Manager
# Douglas  29882.000000        8
# Hermann  30425.708333       12
# Martha   33749.500000       14
# Timothy  25446.444444        9

# %% [markdown]
# ## find manager wise, salesman wise total sale and also display the sum of all sale amount at the bottom

# %%
table = pd.pivot_table(df,index=["Manager","SalesMan"],values=["Units","Sale_amt"],
               aggfunc=[np.sum],fill_value=0,margins=True)

# %% [markdown]
# ## find the total sale amount region wise, manager wise, sales man wise

# %%
table = pd.pivot_table(df,index=["Region","Manager","SalesMan"], values="Sale_amt")
print(table.query('Manager == ["Douglas"]'))
# Out:
#                               Sale_amt
# Region  Manager SalesMan
# Central Douglas John      41338.666667
# East    Douglas Karen     16068.000000
# West    Douglas Michael   33418.000000

# %% [markdown]
# ## find the maximum and minimum sale value of the items

# %%
table = pd.pivot_table(df, index='Item', values='Sale_amt', aggfunc=[np.max, np.min])

# %% [markdown]
# # Pandas Style exercise

# %%
df_nba = pd.read_csv('resources/nba.csv')

# %%
df_nba.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
df_nba[['Age']].style.applymap(color_negative_red)
# Out:
# <style type="text/css">
# #T_c2d1d_row0_col0, #T_c2d1d_row1_col0, #T_c2d1d_row2_col0, #T_c2d1d_row3_col0, #T_c2d1d_row4_col0, #T_c2d1d_row5_col0, #T_c2d1d_row6_col0, #T_c2d1d_row7_col0, #T_c2d1d_row8_col0, #T_c2d1d_row9_col0, #T_c2d1d_row10_col0, #T_c2d1d_row11_col0, #T_c2d1d_row12_col0, #T_c2d1d_row13_col0, #T_c2d1d_row14_col0, #T_c2d1d_row15_col0, #T_c2d1d_row16_col0, #T_c2d1d_row17_col0, #T_c2d1d_row18_col0, #T_c2d1d_row19_col0, #T_c2d1d_row20_col0, #T_c2d1d_row21_col0, #T_c2d1d_row22_col0, #T_c2d1d_row23_col0, #T_c2d1d_row24_col0, #T_c2d1d_row25_col0, #T_c2d1d_row26_col0, #T_c2d1d_row27_col0, #T_c2d1d_row28_col0, #T_c2d1d_row29_col0, #T_c2d1d_row30_col0, #T_c2d1d_row31_col0, #T_c2d1d_row32_col0, #T_c2d1d_row33_col0, #T_c2d1d_row34_col0, #T_c2d1d_row35_col0, #T_c2d1d_row36_col0, #T_c2d1d_row37_col0, #T_c2d1d_row38_col0, #T_c2d1d_row39_col0, #T_c2d1d_row40_col0, #T_c2d1d_row41_col0, #T_c2d1d_row42_col0, #T_c2d1d_row43_col0, #T_c2d1d_row44_col0, #T_c2d1d_row45_col0, #T_c2d1d_row46_col0, #T_c2d1d_row47_col0, #T_c2d1d_row48_col0, #T_c2d1d_row49_col0, #T_c2d1d_row50_col0, #T_c2d1d_row51_col0, #T_c2d1d_row52_col0, #T_c2d1d_row53_col0, #T_c2d1d_row54_col0, #T_c2d1d_row55_col0, #T_c2d1d_row56_col0, #T_c2d1d_row57_col0, #T_c2d1d_row58_col0, #T_c2d1d_row59_col0, #T_c2d1d_row60_col0, #T_c2d1d_row61_col0, #T_c2d1d_row62_col0, #T_c2d1d_row63_col0, #T_c2d1d_row64_col0, #T_c2d1d_row65_col0, #T_c2d1d_row66_col0, #T_c2d1d_row67_col0, #T_c2d1d_row68_col0, #T_c2d1d_row69_col0, #T_c2d1d_row70_col0, #T_c2d1d_row71_col0, #T_c2d1d_row72_col0, #T_c2d1d_row73_col0, #T_c2d1d_row74_col0, #T_c2d1d_row75_col0, #T_c2d1d_row76_col0, #T_c2d1d_row77_col0, #T_c2d1d_row78_col0, #T_c2d1d_row79_col0, #T_c2d1d_row80_col0, #T_c2d1d_row81_col0, #T_c2d1d_row82_col0, #T_c2d1d_row83_col0, #T_c2d1d_row84_col0, #T_c2d1d_row85_col0, #T_c2d1d_row86_col0, #T_c2d1d_row87_col0, #T_c2d1d_row88_col0, #T_c2d1d_row89_col0, #T_c2d1d_row90_col0, #T_c2d1d_row91_col0, #T_c2d1d_row92_col0, #T_c2d1d_row93_col0, #T_c2d1d_row94_col0, #T_c2d1d_row95_col0, #T_c2d1d_row96_col0, #T_c2d1d_row97_col0, #T_c2d1d_row98_col0, #T_c2d1d_row99_col0, #T_c2d1d_row100_col0, #T_c2d1d_row101_col0, #T_c2d1d_row102_col0, #T_c2d1d_row103_col0, #T_c2d1d_row104_col0, #T_c2d1d_row105_col0, #T_c2d1d_row106_col0, #T_c2d1d_row107_col0, #T_c2d1d_row108_col0, #T_c2d1d_row109_col0, #T_c2d1d_row110_col0, #T_c2d1d_row111_col0, #T_c2d1d_row112_col0, #T_c2d1d_row113_col0, #T_c2d1d_row114_col0, #T_c2d1d_row115_col0, #T_c2d1d_row116_col0, #T_c2d1d_row117_col0, #T_c2d1d_row118_col0, #T_c2d1d_row119_col0, #T_c2d1d_row120_col0, #T_c2d1d_row121_col0, #T_c2d1d_row122_col0, #T_c2d1d_row123_col0, #T_c2d1d_row124_col0, #T_c2d1d_row125_col0, #T_c2d1d_row126_col0, #T_c2d1d_row127_col0, #T_c2d1d_row128_col0, #T_c2d1d_row129_col0, #T_c2d1d_row130_col0, #T_c2d1d_row131_col0, #T_c2d1d_row132_col0, #T_c2d1d_row133_col0, #T_c2d1d_row134_col0, #T_c2d1d_row135_col0, #T_c2d1d_row136_col0, #T_c2d1d_row137_col0, #T_c2d1d_row138_col0, #T_c2d1d_row139_col0, #T_c2d1d_row140_col0, #T_c2d1d_row141_col0, #T_c2d1d_row142_col0, #T_c2d1d_row143_col0, #T_c2d1d_row144_col0, #T_c2d1d_row145_col0, #T_c2d1d_row146_col0, #T_c2d1d_row147_col0, #T_c2d1d_row148_col0, #T_c2d1d_row149_col0, #T_c2d1d_row150_col0, #T_c2d1d_row151_col0, #T_c2d1d_row152_col0, #T_c2d1d_row153_col0, #T_c2d1d_row154_col0, #T_c2d1d_row155_col0, #T_c2d1d_row156_col0, #T_c2d1d_row157_col0, #T_c2d1d_row158_col0, #T_c2d1d_row159_col0, #T_c2d1d_row160_col0, #T_c2d1d_row161_col0, #T_c2d1d_row162_col0, #T_c2d1d_row163_col0, #T_c2d1d_row164_col0, #T_c2d1d_row165_col0, #T_c2d1d_row166_col0, #T_c2d1d_row167_col0, #T_c2d1d_row168_col0, #T_c2d1d_row169_col0, #T_c2d1d_row170_col0, #T_c2d1d_row171_col0, #T_c2d1d_row172_col0, #T_c2d1d_row173_col0, #T_c2d1d_row174_col0, #T_c2d1d_row175_col0, #T_c2d1d_row176_col0, #T_c2d1d_row177_col0, #T_c2d1d_row178_col0, #T_c2d1d_row179_col0, #T_c2d1d_row180_col0, #T_c2d1d_row181_col0, #T_c2d1d_row182_col0, #T_c2d1d_row183_col0, #T_c2d1d_row184_col0, #T_c2d1d_row185_col0, #T_c2d1d_row186_co ...

# %%
def color_negative_red(val):
    #print(val)
    color = 'red' if val > 90 else 'green'
    return 'color: % s' % color

# displaying the DataFrame
#df_nba.style.applymap(color_negative_red)
